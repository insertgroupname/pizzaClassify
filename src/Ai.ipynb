# %%
import numpy as np
import os
import tensorflow as tf
import PIL
import pathlib
import sys
from PIL import Image

data_dir = '../content/pizzaGANdata/pizzaGANdata/images'
data = pathlib.Path(data_dir)
image_count = len(list(data.glob('*.jpg')))
print(image_count)
